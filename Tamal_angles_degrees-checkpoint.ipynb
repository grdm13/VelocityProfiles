# %%
cd "C:\Users\Dino\Box\1. Projects\12. Tamal Dentistry Project\csv_angle"
# Out:
# C:\Users\Dino\Box\1. Projects\12. Tamal Dentistry Project\csv_angle

# %%
import cv2
import pandas as pd
import numpy as np

# %%
# Get a VideoCapture object from video and store it in vs
vc = cv2.VideoCapture('C://Users//Dino//Box//1. Projects//12. Tamal Dentistry Project//green_side_h0mm_us10_pos1_1_1.cine')
# Read first frame
ret, first_frame = vc.read()
# Scale and resize image
resize_dim = 600
max_dim = max(first_frame.shape)
scale = resize_dim / max_dim
first_frame = cv2.resize(first_frame, None, fx=scale, fy=scale)
# Convert to gray scale
prev_gray = cv2.cvtColor(first_frame, cv2.COLOR_BGR2GRAY)
# Create mask
mask = np.zeros_like(first_frame)
# Sets image saturation to maximum
mask[..., 1] = 255
out = cv2.VideoWriter('video.mp4', -1, 1, (600, 600))

# %%
    width = vc.get(cv2.CAP_PROP_FRAME_WIDTH)  # float
    height = vc.get(cv2.CAP_PROP_FRAME_HEIGHT)  # float
    print('width, height:', width, height)
    fps = vc.get(cv2.CAP_PROP_FPS)
    print('fps:', fps)  # float
    frame_count = vc.get(cv2.CAP_PROP_FRAME_COUNT)
    print('frames count:', frame_count)  # float
# Out:
# width, height: 1280.0 800.0
# fps: 3200.0
# frames count: 113.0

# %%
i=0
while (vc.isOpened()):

    i=i+1
    # Read a frame from video
    ret, frame = vc.read()
    # Convert new frame format`s to gray scale and resize gray frame obtained
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, None, fx=scale, fy=scale)
    #cv2.imwrite("frame number {0}.jpg".format(i), gray)
    # Calculate dense optical flow by Farneback method
    # https://docs.opencv.org/3.0-beta/modules/video/doc/motion_analysis_and_object_tracking.html#calcopticalflowfarneback
    flow = cv2.calcOpticalFlowFarneback(prev_gray, gray, None, pyr_scale=0.5, levels=5, winsize=11, iterations=5,
                                        poly_n=5, poly_sigma=1.1, flags=0)
    # Compute the magnitude and angle of the 2D vectors
    magnitude, angle = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    
    
    angle_degrees = angle * 57.2958
    
    df = pd.DataFrame(( angle_degrees))
    df.to_csv(f'angle matrix from {i} frame.csv', index=False)  # save as csv
    print(f'angles matrix from {i} frame printed')
    # Set image hue according to the optical flow direction
    mask[..., 0] = angle * 180 / np.pi / 2
    # Set image value according to the optical flow magnitude (normalized)
    mask[..., 2] = cv2.normalize(magnitude, None, 0, 255, cv2.NORM_MINMAX)
    # Convert HSV to RGB (BGR) color representation
    rgb = cv2.cvtColor(mask, cv2.COLOR_HSV2BGR)
    # Resize frame size to match dimensions
    frame = cv2.resize(frame, None, fx=scale, fy=scale)
    # Open a new window and displays the output frame
    dense_flow = cv2.addWeighted(frame, 1, rgb, 2, 0)

    #cv2.imshow("Dense optical flow", dense_flow)

    out.write(dense_flow)
    # Update previous frame
    prev_gray = gray
    # Frame are read by intervals of 1 millisecond. The programs breaks out of the while loop when the user presses the 'q' key
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
# The following frees up resources and closes all windows
vc.release()
# Out:
# angles matrix from 1 frame printed
# angles matrix from 2 frame printed
# angles matrix from 3 frame printed
# angles matrix from 4 frame printed
# angles matrix from 5 frame printed
# angles matrix from 6 frame printed
# angles matrix from 7 frame printed
# angles matrix from 8 frame printed
# angles matrix from 9 frame printed
# angles matrix from 10 frame printed
# angles matrix from 11 frame printed
# angles matrix from 12 frame printed
# angles matrix from 13 frame printed
# angles matrix from 14 frame printed
# angles matrix from 15 frame printed
# angles matrix from 16 frame printed
# angles matrix from 17 frame printed
# angles matrix from 18 frame printed
# angles matrix from 19 frame printed
# angles matrix from 20 frame printed
# angles matrix from 21 frame printed
# angles matrix from 22 frame printed
# angles matrix from 23 frame printed
# angles matrix from 24 frame printed
# angles matrix from 25 frame printed
# angles matrix from 26 frame printed
# angles matrix from 27 frame printed
# angles matrix from 28 frame printed
# angles matrix from 29 frame printed
# angles matrix from 30 frame printed
# angles matrix from 31 frame printed
# angles matrix from 32 frame printed
# angles matrix from 33 frame printed
# angles matrix from 34 frame printed
# angles matrix from 35 frame printed
# angles matrix from 36 frame printed
# angles matrix from 37 frame printed
# angles matrix from 38 frame printed
# angles matrix from 39 frame printed
# angles matrix from 40 frame printed
# angles matrix from 41 frame printed
# angles matrix from 42 frame printed
# angles matrix from 43 frame printed
# angles matrix from 44 frame printed
# angles matrix from 45 frame printed
# angles matrix from 46 frame printed
# angles matrix from 47 frame printed
# angles matrix from 48 frame printed
# angles matrix from 49 frame printed
# angles matrix from 50 frame printed
# angles matrix from 51 frame printed
# angles matrix from 52 frame printed
# angles matrix from 53 frame printed
# angles matrix from 54 frame printed
# angles matrix from 55 frame printed
# angles matrix from 56 frame printed
# angles matrix from 57 frame printed
# angles matrix from 58 frame printed
# angles matrix from 59 frame printed
# angles matrix from 60 frame printed
# angles matrix from 61 frame printed
# angles matrix from 62 frame printed
# angles matrix from 63 frame printed
# angles matrix from 64 frame printed
# angles matrix from 65 frame printed
# angles matrix from 66 frame printed
# angles matrix from 67 frame printed
# angles matrix from 68 frame printed
# angles matrix from 69 frame printed
# angles matrix from 70 frame printed
# angles matrix from 71 frame printed
# angles matrix from 72 frame printed
# angles matrix from 73 frame printed
# angles matrix from 74 frame printed
# angles matrix from 75 frame printed
# angles matrix from 76 frame printed
# angles matrix from 77 frame printed
# angles matrix from 78 frame printed
# angles matrix from 79 frame printed
# angles matrix from 80 frame printed
# angles matrix from 81 frame printed
# angles matrix from 82 frame printed
# angles matrix from 83 frame printed
# angles matrix from 84 frame printed
# angles matrix from 85 frame printed
# angles matrix from 86 frame printed
# angles matrix from 87 frame printed
# angles matrix from 88 frame printed
# angles matrix from 89 frame printed
# angles matrix from 90 frame printed
# angles matrix from 91 frame printed
# angles matrix from 92 frame printed
# angles matrix from 93 frame printed
# angles matrix from 94 frame printed
# angles matrix from 95 frame printed
# angles matrix from 96 frame printed
# angles matrix from 97 frame printed
# angles matrix from 98 frame printed
# angles matrix from 99 frame printed
# angles matrix from 100 frame printed
# angles matrix from 101 frame printed
# angles matrix from 102 frame printed
# angles matrix from 103 frame printed
# angles matrix from 104 frame printed
# angles matrix from 105 frame printed
# angles matrix from 106 frame printed
# angles matrix from 107 frame printed
# angles matrix from 108 frame printed
# angles matrix from 109 frame printed
# angles matrix from 110 frame printed
# angles matrix from 111 frame printed
# angles matrix from 112 frame printed
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-297d260ec37c> in <module>
#       6     ret, frame = vc.read()
#       7     # Convert new frame format`s to gray scale and resize gray frame obtained
# ----> 8     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       9     gray = cv2.resize(gray, None, fx=scale, fy=scale)
#      10     #cv2.imwrite("frame number {0}.jpg".format(i), gray)
#
# error: OpenCV(3.4.5) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:181: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
